# %%
#!pip install matplotlib
#!pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 0047-F845
#
#  Directory of C:\Users\tomil
#
# 08/08/2022  22:25    <DIR>          .
# 22/07/2022  01:01    <DIR>          ..
# 08/08/2022  21:52               985 .bash_history
# 31/07/2022  19:15                55 .gitconfig
# 08/08/2022  21:53    <DIR>          .ipynb_checkpoints
# 30/07/2022  12:27    <DIR>          .ipython
# 30/07/2022  15:12    <DIR>          .jupyter
# 08/08/2022  22:10    <DIR>          .matplotlib
# 06/06/2022  17:28    <DIR>          .vscode
# 02/05/2021  01:34    <DIR>          3D Objects
# 22/07/2022  01:07    <DIR>          Contacts
# 26/07/2022  21:54    <DIR>          data_1.01_activities
# 02/08/2022  11:28    <DIR>          Documents
# 03/08/2022  21:45    <DIR>          Downloads
# 22/07/2022  01:07    <DIR>          Favorites
# 02/08/2022  11:18    <DIR>          IronTomilola
# 04/08/2022  10:55    <DIR>          lab-bash
# ...

# %%
cd lab-customer-analysis-round-3
# Out:
# C:\Users\tomil\lab-customer-analysis-round-3

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 0047-F845
#
#  Directory of C:\Users\tomil\lab-customer-analysis-round-3
#
# 08/08/2022  21:51    <DIR>          .
# 08/08/2022  22:31    <DIR>          ..
# 08/08/2022  21:51    <DIR>          .github
# 08/08/2022  21:51    <DIR>          files_for_lab
# 08/08/2022  21:51               753 readme.md
#                1 File(s)            753 bytes
#                4 Dir(s)  427,466,043,392 bytes free

# %%
cd files_for_lab
# Out:
# C:\Users\tomil\lab-customer-analysis-round-3\files_for_lab

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 0047-F845
#
#  Directory of C:\Users\tomil\lab-customer-analysis-round-3\files_for_lab
#
# 08/08/2022  21:51    <DIR>          .
# 08/08/2022  21:51    <DIR>          ..
# 08/08/2022  21:51               273 about.md
# 08/08/2022  21:51    <DIR>          csv_files
# 08/08/2022  21:51    <DIR>          excel_files
#                1 File(s)            273 bytes
#                4 Dir(s)  427,465,904,128 bytes free

# %%
cd csv_files
# Out:
# C:\Users\tomil\lab-customer-analysis-round-3\files_for_lab\csv_files

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 0047-F845
#
#  Directory of C:\Users\tomil\lab-customer-analysis-round-3\files_for_lab\csv_files
#
# 08/08/2022  21:51    <DIR>          .
# 08/08/2022  21:51    <DIR>          ..
# 08/08/2022  21:51         1,581,918 marketing_customer_analysis.csv
#                1 File(s)      1,581,918 bytes
#                2 Dir(s)  427,465,912,320 bytes free

# %%
df = pd.read_csv('marketing_customer_analysis.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
df.shape
# Out:
# (9134, 24)

# %%
df.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
# dataframe is a data structure that organizes data into a dimentional tables of rows and columns,much like a spreadsheet.
df.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
summary = df.describe().T
display(summary)
# Out:
#                                 count          mean           std  \
# Customer Lifetime Value        9134.0   8004.940475   6870.967608
# Income                         9134.0  37657.380009  30379.904734
# Monthly Premium Auto           9134.0     93.219291     34.407967
# Months Since Last Claim        9134.0     15.097000     10.073257
# Months Since Policy Inception  9134.0     48.064594     27.905991
# Number of Open Complaints      9134.0      0.384388      0.910384
# Number of Policies             9134.0      2.966170      2.390182
# Total Claim Amount             9134.0    434.088794    290.500092
#
#                                        min          25%           50%  \
# Customer Lifetime Value        1898.007675  3994.251794   5780.182197
# Income                            0.000000     0.000000  33889.500000
# Monthly Premium Auto             61.000000    68.000000     83.000000
# Months Since Last Claim           0.000000     6.000000     14.000000
# ...

# %%
summary["iqr"] = summary["75%"] - summary["25%"]
summary
# Out:
#                                 count          mean           std  \
# Customer Lifetime Value        9134.0   8004.940475   6870.967608
# Income                         9134.0  37657.380009  30379.904734
# Monthly Premium Auto           9134.0     93.219291     34.407967
# Months Since Last Claim        9134.0     15.097000     10.073257
# Months Since Policy Inception  9134.0     48.064594     27.905991
# Number of Open Complaints      9134.0      0.384388      0.910384
# Number of Policies             9134.0      2.966170      2.390182
# Total Claim Amount             9134.0    434.088794    290.500092
#
#                                        min          25%           50%  \
# Customer Lifetime Value        1898.007675  3994.251794   5780.182197
# Income                            0.000000     0.000000  33889.500000
# Monthly Premium Auto             61.000000    68.000000     83.000000
# Months Since Last Claim           0.000000     6.000000     14.000000
# ...

# %%
df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
df["Response"].hist()
# Out:
# <AxesSubplot:>

# %%
df["Customer Lifetime Value"].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
sns.displot(df["Customer Lifetime Value"],bins=100)

# %%
summary
# Out:
#                                 count          mean           std  \
# Customer Lifetime Value        9134.0   8004.940475   6870.967608
# Income                         9134.0  37657.380009  30379.904734
# Monthly Premium Auto           9134.0     93.219291     34.407967
# Months Since Last Claim        9134.0     15.097000     10.073257
# Months Since Policy Inception  9134.0     48.064594     27.905991
# Number of Open Complaints      9134.0      0.384388      0.910384
# Number of Policies             9134.0      2.966170      2.390182
# Total Claim Amount             9134.0    434.088794    290.500092
#
#                                        min          25%           50%  \
# Customer Lifetime Value        1898.007675  3994.251794   5780.182197
# Income                            0.000000     0.000000  33889.500000
# Monthly Premium Auto             61.000000    68.000000     83.000000
# Months Since Last Claim           0.000000     6.000000     14.000000
# ...

# %%
sns.displot(df["Total Claim Amount"],bins=100)

# %%
sns.displot(df["Income"],bins=100)
